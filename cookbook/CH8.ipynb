# %%
# %pylab inline
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
popcon = pd.read_csv('./../data/popularity-contest',
                    sep=' ')[:-1]
popcon.columns = ['atime','ctime','package-name','mru-program','tag']

# %%
popcon['atime'] = popcon['atime'].astype(int)
popcon['ctime'] = popcon['ctime'].astype(int)

# %%
popcon['atime'] = pd.to_datetime( popcon['atime'],unit='s')
popcon['ctime'] = pd.to_datetime( popcon['ctime'],unit='s')

# %%
notlib=(~popcon['mru-program'].str.contains('lib'))

# %%
popcon[notlib]
# Out:
#                    atime               ctime  \
# 0    2013-12-17 15:56:37 2013-05-04 02:07:40
# 1    2013-12-17 15:56:36 2012-12-01 14:01:20
# 18   2013-12-17 15:55:32 2012-12-01 05:53:57
# 19   2013-12-17 15:55:29 2012-12-01 05:54:37
# 20   2013-12-17 15:53:05 2012-12-01 05:54:16
# 21   2013-12-17 15:53:05 2013-11-25 16:00:20
# 22   2013-12-17 15:53:05 2012-12-01 14:01:16
# 23   2013-12-17 15:53:05 2012-12-01 05:54:15
# 26   2013-12-17 15:52:53 2012-12-01 05:54:16
# 27   2013-12-17 15:52:53 2012-12-01 05:54:37
# 28   2013-12-17 15:52:49 2012-12-01 05:54:13
# 29   2013-12-17 15:52:49 2013-12-10 16:22:37
# 30   2013-12-17 15:52:49 2012-12-01 05:54:15
# 43   2013-12-17 04:55:50 2013-10-29 03:28:19
# 54   2013-12-17 04:55:44 2012-12-01 05:54:14
# 56   2013-12-17 04:55:42 2012-12-01 05:54:57
# 57   2013-12-17 04:55:39 2013-12-17 04:55:42
# 58   2013-12-17 04:55:39 2012-12-01 05:53:59
# 60   2013-12-17 04:55:38 2012-12-01 05:54:57
# 64   2013-12-17 04:55:38 2012-12-01 05:53:57
# 66   2013-12-17 04:55:38 2013-12-10 16:24:47
# 68   2013-12-17 04:47:50 2012-12-01 05:54:16
# 79   2013-12-17 04:44:40 2013-11-25 16:16:13
# 83   2013-12-17 04:44:40 2013-11-25 16:07:09
# 86   2013-12-17 04:44:40 2013-11-25 16:07:09
# 90   2013-12-17 04:43:44 2012-12-01 05:54:15
# 92   2013-12-17 04:43:17 2012-12-01 15:35:48
# 94   2013-12-17 04:34:03 2013-11-25 22:23:32
# 97   2013-12-17 04:28:15 2012-12-01 05:54:13
# 106  2013-12-17 04:28:03 2013-12-10 16:25:09
# ...                  ...                 ...
# 2867 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2868 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2869 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2870 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2871 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2872 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2873 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2874 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2875 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2876 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2877 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2878 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2879 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2880 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2881 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2882 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2883 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2884 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2885 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2886 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2887 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2888 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2889 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2890 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2891 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2892 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2893 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2894 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2895 1970-01-01 00:00:00 1970-01-01 00:00:00
# 2896 1970-01-01 00:00:00 1970-01-01 00:00:00
#
#                                 package-name  \
# 0                                  perl-base
# 1                                      login
# 18                                      dash
# 19                        popularity-contest
# 20                                   mlocate
# 21                                      dpkg
# 22                                 coreutils
# 23                                util-linux
# 26                                 findutils
# 27                                 logrotate
# 28                                 diffutils
# 29                                       apt
# 30                               debianutils
# 43                                  libc-bin
# 54                              install-info
# 56                                   debconf
# 57                                       ddd
# 58                                       tar
# 60                     libtext-wrapi18n-perl
# 64                                      gzip
# 66                                 apt-utils
# 68                                groff-base
# 79                               lsb-release
# 83                         python2.7-minimal
# 86                            python-minimal
# 90                                     rsync
# 92                                        sl
# 94                      google-chrome-stable
# 97                                    aspell
# 106                                ruby1.9.1
# ...                                      ...
# 2867                            gnumeric-doc
# 2868                         libplank-common
# 2869                      libopencore-amrwb0
# 2870                      libgweather-common
# 2871                                 libzmq1
# 2872                       libdjvulibre-text
# 2873                           libjtidy-java
# 2874                        libopenlibm-base
# 2875                              libarpack2
# 2876                             libssl0.9.8
# 2877              python-scikits.statsmodels
# 2878                          python-sklearn
# 2879                             libmodplug1
# 2880                             libvlccore5
# 2881                              libgck-1-0
# 2882                           libxcb-icccm4
# 2883                             gsfonts-x11
# 2884                   elementary-wallpapers
# 2885          libboost-program-options1.49.0
# 2886                   gnome-icon-theme-full
# 2887                           libgtkhotkey1
# 2888                           libvncserver0
# 2889                             libspeechd2
# 2890    elementaryos-report-problem-dockitem
# 2891              print-test-page-elementary
# 2892                         libreadline-dev
# 2893                        notify-osd-icons
# 2894                       python-apt-common
# 2895  libindicator-messages-status-provider1
# 2896                             libusbmuxd1
#
#                               mru-program             tag
# 0                           /usr/bin/perl             NaN
# 1                                 /bin/su             NaN
# 18                              /bin/dash             NaN
# 19           /usr/sbin/popularity-contest             NaN
# 20              /usr/bin/updatedb.mlocate             NaN
# 21            /usr/sbin/dpkg-statoverride             NaN
# 22                              /bin/true             NaN
# 23                        /usr/bin/ionice             NaN
# 26                         /usr/bin/xargs             NaN
# 27                    /usr/sbin/logrotate             NaN
# 28                           /usr/bin/cmp             NaN
# 29                    /usr/bin/apt-config             NaN
# 30                       /usr/bin/savelog             NaN
# 43                    /sbin/ldconfig.real             NaN
# 54                 /usr/bin/ginstall-info             NaN
# 56    /usr/share/perl5/Debconf/Element.pm             NaN
# 57                           /usr/bin/ddd  <RECENT-CTIME>
# 58                               /bin/tar             NaN
# 60      /usr/share/perl5/Text/WrapI18N.pm             NaN
# 64                              /bin/gzip             NaN
# 66          /usr/bin/apt-extracttemplates             NaN
# 68                          /usr/bin/gtbl             NaN
# 79                   /usr/bin/lsb_release             NaN
# 83                     /usr/bin/python2.7             NaN
# 86                        /usr/bin/python             NaN
# 90                         /usr/bin/rsync             NaN
# 92                          /usr/games/LS             NaN
# 94          /usr/bin/google-chrome-stable             NaN
# 97                        /usr/bin/aspell             NaN
# 106                    /usr/bin/ruby1.9.1             NaN
# ...                                   ...             ...
# 2867                            <NOFILES>             NaN
# 2868                            <NOFILES>             NaN
# 2869                            <NOFILES>             NaN
# 2870                            <NOFILES>             NaN
# 2871                            <NOFILES>             NaN
# 2872                            <NOFILES>             NaN
# 2873                            <NOFILES>             NaN
# 2874                            <NOFILES>             NaN
# 2875                            <NOFILES>             NaN
# 2876                            <NOFILES>             NaN
# 2877                            <NOFILES>             NaN
# 2878                            <NOFILES>             NaN
# 2879                            <NOFILES>             NaN
# 2880                            <NOFILES>             NaN
# 2881                            <NOFILES>             NaN
# 2882                            <NOFILES>             NaN
# 2883                            <NOFILES>             NaN
# 2884                            <NOFILES>             NaN
# 2885                            <NOFILES>             NaN
# 2886                            <NOFILES>             NaN
# 2887                            <NOFILES>             NaN
# 2888                            <NOFILES>             NaN
# 2889                            <NOFILES>             NaN
# 2890                            <NOFILES>             NaN
# 2891                            <NOFILES>             NaN
# 2892                            <NOFILES>             NaN
# 2893                            <NOFILES>             NaN
# 2894                            <NOFILES>             NaN
# 2895                            <NOFILES>             NaN
# 2896                            <NOFILES>             NaN
#
# [1436 rows x 5 columns]
